# %%
import hamiltonian
import basis_states
import networkx as nx
import numpy as np

# %%
ham = hamiltonian.H(4, 1, 1, 1)

# %%
nx.draw(ham.get_graph(edge_relation='C'), width=0.2)

# %%
adj_matrix = ham.adjacency_matrix

# %%
ham[np.sum(adj_matrix, axis=1) == adj_matrix.shape[1]]
# Out:
#  5.688+0.000j IIIIIIII
